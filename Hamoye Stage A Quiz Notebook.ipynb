# %%
import pandas as pd

# %%
fuel_dataset_link = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_dataset = pd.read_csv(fuel_dataset_link,error_bad_lines=False)

# %%
A = [1,2,3,4,5,6]

# %%
B = [13, 21, 34]

# %%
A.append(B)

# %%
print(A)
# Out:
# [1, 2, 3, 4, 5, 6, [13, 21, 34]]

# %%
A.extend(B)

# %%
print(A)
# Out:
# [1, 2, 3, 4, 5, 6, [13, 21, 34], 13, 21, 34]

# %%
import numpy as np
np.array([1,0,0],[0,1,0],[0,0,1]) #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8c031868e442> in <module>
#       1 import numpy as np
# ----> 2 np.array([1,0,0],[0,1,0],[0,0,1])
#
# TypeError: array() takes from 1 to 2 positional arguments but 3 were given

# %%
fuel_dataset.describe(include='all')
# Out:
#                        record_id  utility_id_ferc1   report_year  \
# count                      29523      29523.000000  29523.000000
# unique                     29523               NaN           NaN
# top     f1_fuel_2000_12_120_2_14               NaN           NaN
# freq                           1               NaN           NaN
# mean                         NaN        118.601836   2005.806050
# std                          NaN         74.178353      7.025483
# min                          NaN          1.000000   1994.000000
# 25%                          NaN         55.000000   2000.000000
# 50%                          NaN        122.000000   2006.000000
# 75%                          NaN        176.000000   2012.000000
# max                          NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
fuel_dataset.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_dataset.isnull().mean() * 100
# Out:
# record_id                       0.000000
# utility_id_ferc1                0.000000
# report_year                     0.000000
# plant_name_ferc1                0.000000
# fuel_type_code_pudl             0.000000
# fuel_unit                       0.609694
# fuel_qty_burned                 0.000000
# fuel_mmbtu_per_unit             0.000000
# fuel_cost_per_unit_burned       0.000000
# fuel_cost_per_unit_delivered    0.000000
# fuel_cost_per_mmbtu             0.000000
# dtype: float64

# %%
fuel_dataset.groupby('fuel_type_code_pudl')['fuel_type_code_pudl'].count()
# Out:
# fuel_type_code_pudl
# coal        8547
# gas        11486
# nuclear      818
# oil         8064
# other        167
# waste        441
# Name: fuel_type_code_pudl, dtype: int64

# %%
print(fuel_dataset)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
corr = fuel_dataset.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.heatmap(corr, annot=True)
plt.show()

# %%
fuel_dataset.mode()
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_1994_12_100_0_1             194.0       2000.0
# 1      f1_fuel_1994_12_100_0_11               NaN          NaN
# 2      f1_fuel_1994_12_100_0_14               NaN          NaN
# 3      f1_fuel_1994_12_100_0_15               NaN          NaN
# 4       f1_fuel_1994_12_100_0_3               NaN          NaN
# ...                         ...               ...          ...
# 29518    f1_fuel_2018_12_99_0_2               NaN          NaN
# 29519    f1_fuel_2018_12_99_0_7               NaN          NaN
# 29520   f1_fuel_2018_12_99_1_10               NaN          NaN
# 29521   f1_fuel_2018_12_99_1_13               NaN          NaN
# 29522    f1_fuel_2018_12_99_1_4               NaN          NaN
#
#       plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0            big stone                 gas       mcf              1.0
# ...

# %%
fuel_dataset=fuel_dataset.dropna(subset=['report_year'])

# %%
fuel_dataset.mode()
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_1994_12_100_0_1             194.0       2000.0
# 1      f1_fuel_1994_12_100_0_11               NaN          NaN
# 2      f1_fuel_1994_12_100_0_14               NaN          NaN
# 3      f1_fuel_1994_12_100_0_15               NaN          NaN
# 4       f1_fuel_1994_12_100_0_3               NaN          NaN
# ...                         ...               ...          ...
# 29518    f1_fuel_2018_12_99_0_2               NaN          NaN
# 29519    f1_fuel_2018_12_99_0_7               NaN          NaN
# 29520   f1_fuel_2018_12_99_1_10               NaN          NaN
# 29521   f1_fuel_2018_12_99_1_13               NaN          NaN
# 29522    f1_fuel_2018_12_99_1_4               NaN          NaN
#
#       plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0            big stone                 gas       mcf              1.0
# ...
